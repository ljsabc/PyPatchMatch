# %%
! apt -y install build-essential libopencv-dev
! git clone https://github.com/ljsabc/PyPatchMatch.git
# %cd PyPatchMatch
! make clean && make -j5
# %cd ..
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# libopencv-dev is already the newest version (4.5.4+dfsg-9ubuntu4).
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.
# Cloning into 'PyPatchMatch'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 146 (delta 56), reused 51 (delta 51), pack-reused 75
# Receiving objects: 100% (146/146), 1.05 MiB | 2.71 MiB/s, done.
# Resolving deltas: 100% (87/87), done.
# /content/PyPatchMatch
# mkdir: created directory 'build'
# mkdir: created directory 'build/obj'
# mkdir: created directory 'build/obj/csrc/'
# [dep] csrc/masked_image.cpp ...
# [dep] csrc/inpaint.cpp ...
# [dep] csrc/nnf.cpp ...
# [dep] csrc/pyinterface.cpp ...
# rm -rf build/obj libpatchmatch.so
# mkdir: created directory 'build/obj'
# ...

# %%
! cp ./PyPatchMatch/libpatchmatch.so ./PyPatchMatch/patch_match.py ./

# %%
import cv2
import patch_match
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('image.png')

# Convert the image from BGR to RGB
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Load the mask using cv2
mask = cv2.imread('mask.png', 0)

# Call the inpaint function from patch_match
result = patch_match.inpaint(image, mask, patch_size=5)

#result = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>
